# %%
import papermill as pm

input_notebook = "merge.ipynb"

params_list = [
    {"path": "../dane/8CPU_20RAM/3600s/2repl/"},
    {"path": "../dane/8CPU_20RAM/3600s/4repl/"},
    {"path": "../dane/8CPU_20RAM/3600s/5repl/"},
    {"path": "../dane/8CPU_20RAM/3600s/6repl/"},
    {"path": "../dane/8CPU_20RAM/3600s/A1_100-A2_100-A3_100/"},
    {"path": "../dane/8CPU_20RAM/3600s/A1_200-A3_100/"},
    {"path": "../dane/8CPU_20RAM/3600s/A2_200/"},
    {"path": "../dane/8CPU_20RAM/3600s/A2_200-A3_100/"},
    {"path": "../dane/8CPU_20RAM/3600s/A3_200/"},
    {"path": "../dane/8CPU_20RAM/3600s/req_250ms/"},
    {"path": "../dane/8CPU_20RAM/3600s/req_500ms/"},
    {"path": "../dane/8CPU_20RAM/3600s/req_1000ms/"},
    {"path": "../dane/8CPU_20RAM/3600s/req_2000ms/"},
    {"path": "../dane/8CPU_20RAM/3600s/trans_60s/"},
    {"path": "../dane/8CPU_20RAM/3600s/trans_120s/"},
    {"path": "../dane/8CPU_20RAM/3600s/trans_180s/"},
    {"path": "../dane/8CPU_20RAM/3600s/trans_240s/"},
    {"path": "../dane/8CPU_20RAM/3600s/trans_300s/"},
]

for i, params in enumerate(params_list):
    output_notebook = f"merge_{i}.ipynb"
    pm.execute_notebook(input_notebook, output_notebook, parameters=params)
# Out:
# Black is not installed, parameters wont be formatted
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 10/10 [00:07<00:00,  1.28cell/s]
# Black is not installed, parameters wont be formatted
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 10/10 [00:07<00:00,  1.41cell/s]
# Black is not installed, parameters wont be formatted
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 10/10 [00:07<00:00,  1.43cell/s]
# Black is not installed, parameters wont be formatted
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 10/10 [00:06<00:00,  1.46cell/s]
# Black is not installed, parameters wont be formatted
# Input notebook does not contain a cell with tag 'parameters'
# Executing: 100%|██████████| 10/10 [00:05<00:00,  1.69cell/s]
# Black is not installed, parameters wont be formatted
# ...
